# %% [markdown]
# ```
# ': 0.3936, 'eval_samples_per_second': 757.079, 'eval_steps_per_second': 12.703, 'epoch': 76.0}
#  15%|██████████▉                                                             | 1067/7000 [14:08<2:19:48,  1.41s/it]
# RAM Usage: 51.0%
# Used RAM: 113.20GB
# Available RAM: 123.23GB
# GPU 0 Memory Usage: 8319.0MB/24576.0MB (33.9%)
# GPU 1 Memory Usage: 15085.0MB/24576.0MB (61.4%)
# {'loss': 0.0073, 'grad_norm': 15.206793785095215, 'learning_rate': 4.2357142857142864e-05, 'epoch': 76.43}
#  15%|███████████▍                                                              | 1078/7000 [14:10<23:18,  4.24it/sEvaluation - Accuracy: 0.8221, F1 Score: 0.8229███████████████████████████████████████| 5/5 [00:00<00:00, 17.73it/s]
# {'eval_loss': 1.5543463230133057, 'eval_accuracy': 0.8221476510067114, 'eval_f1': 0.8228686567160001, 'eval_runtime': 0.389, 'eval_samples_per_second': 766.027, 'eval_steps_per_second': 12.853, 'epoch': 77.0}
# {'loss': 0.016, 'grad_norm': 0.1597522795200348, 'learning_rate': 4.228571428571429e-05, 'epoch': 77.14}
# {'loss': 0.0124, 'grad_norm': 1.264002799987793, 'learning_rate': 4.221428571428572e-05, 'epoch': 77.86}
#  16%|███████████▌                                                              | 1092/7000 [14:21<23:10,  4.25it/sEvaluation - Accuracy: 0.8356, F1 Score: 0.8359███████████████████████████████████████| 5/5 [00:00<00:00, 17.61it/s]
# {'eval_loss': 1.3899706602096558, 'eval_accuracy': 0.8355704697986577, 'eval_f1': 0.8359292255357214, 'eval_runtime': 0.3902, 'eval_samples_per_second': 763.784, 'eval_steps_per_second': 12.815, 'epoch': 78.0}
# {'loss': 0.002, 'grad_norm': 1.9238734245300293, 'learning_rate': 4.214285714285714e-05, 'epoch': 78.57}
#  16%|███████████▋                                                              | 1106/7000 [14:32<23:13,  4.23it/sEvaluation - Accuracy: 0.8356, F1 Score: 0.8356███████████████████████████████████████| 5/5 [00:00<00:00, 18.07it/s]
# {'eval_loss': 1.386269211769104, 'eval_accuracy': 0.8355704697986577, 'eval_f1': 0.8356472957546425, 'eval_runtime': 0.3776, 'eval_samples_per_second': 789.125, 'eval_steps_per_second': 13.24, 'epoch': 79.0}
#  16%|███████████▋                                                              | 1106/7000 [14:33<23:13,  4.23it/s]
# RAM Usage: 51.3%
# Used RAM: 113.87GB
# Available RAM: 122.56GB
# GPU 0 Memory Usage: 8319.0MB/24576.0MB (33.9%)
# GPU 1 Memory Usage: 15085.0MB/24576.0MB (61.4%)
# {'loss': 0.0007, 'grad_norm': 0.9481902122497559, 'learning_rate': 4.2071428571428574e-05, 'epoch': 79.29}
# {'loss': 0.0003, 'grad_norm': 1.7947040796279907, 'learning_rate': 4.2e-05, 'epoch': 80.0}
#  16%|███████████▊                                                              | 1120/7000 [14:43<23:06,  4.24it/sEvaluation - Accuracy: 0.8289, F1 Score: 0.8286███████████████████████████████████████| 5/5 [00:00<00:00, 17.72it/s]
# {'eval_loss': 1.560558795928955, 'eval_accuracy': 0.8288590604026845, 'eval_f1': 0.8286288196878117, 'eval_runtime': 0.3886, 'eval_samples_per_second': 766.903, 'eval_steps_per_second': 12.867, 'epoch': 80.0}
# {'loss': 0.0185, 'grad_norm': 4.4102325439453125, 'learning_rate': 4.192857142857143e-05, 'epoch': 80.71}
#  16%|███████████▉                                                              | 1134/7000 [14:54<22:57,  4.26it/sEvaluation - Accuracy: 0.8356, F1 Score: 0.8362███████████████████████████████████████| 5/5 [00:00<00:00, 17.66it/s]
# {'eval_loss': 1.4930576086044312, 'eval_accuracy': 0.8355704697986577, 'eval_f1': 0.8361670844834005, 'eval_runtime': 0.39, 'eval_samples_per_second': 764.103, 'eval_steps_per_second': 12.821, 'epoch': 81.0}
# {'loss': 0.0059, 'grad_norm': 0.01529540866613388, 'learning_rate': 4.185714285714286e-05, 'epoch': 81.43}
#  16%|████████████▏                                                             | 1148/7000 [15:05<22:58,  4.25it/sEvaluation - Accuracy: 0.8423, F1 Score: 0.8430███████████████████████████████████████| 5/5 [00:00<00:00, 18.05it/s]
# {'eval_loss': 1.5598015785217285, 'eval_accuracy': 0.8422818791946308, 'eval_f1': 0.8430283646278085, 'eval_runtime': 0.3788, 'eval_samples_per_second': 786.733, 'eval_steps_per_second': 13.2, 'epoch': 82.0}
#  16%|████████████▏                                                             | 1148/7000 [15:06<22:58,  4.25it/s]
# RAM Usage: 51.0%
# Used RAM: 113.17GB
# Available RAM: 123.26GB
# GPU 0 Memory Usage: 8319.0MB/24576.0MB (33.9%)
# GPU 1 Memory Usage: 15085.0MB/24576.0MB (61.4%)
# {'loss': 0.0062, 'grad_norm': 0.003656829707324505, 'learning_rate': 4.178571428571429e-05, 'epoch': 82.14}
# {'loss': 0.0144, 'grad_norm': 0.22360268235206604, 'learning_rate': 4.1714285714285714e-05, 'epoch': 82.86}
#  17%|████████████▎                                                             | 1162/7000 [15:17<22:55,  4.24it/sEvaluation - Accuracy: 0.8188, F1 Score: 0.8202███████████████████████████████████████| 5/5 [00:00<00:00, 17.68it/s]
# {'eval_loss': 1.6309641599655151, 'eval_accuracy': 0.8187919463087249, 'eval_f1': 0.8202264624669607, 'eval_runtime': 0.3899, 'eval_samples_per_second': 764.218, 'eval_steps_per_second': 12.822, 'epoch': 83.0}
# {'loss': 0.0003, 'grad_norm': 0.0035015384200960398, 'learning_rate': 4.1642857142857144e-05, 'epoch': 83.57}
#  17%|████████████▍                                                             | 1172/7000 [15:27<30:21,  3.20it/s]
#
# Giải thích kết quả này
#
# ```

# %% [markdown]
# Kết quả log của bạn là thông tin chi tiết về quá trình huấn luyện mô hình trên từng epoch và step. Dưới đây là giải thích cụ thể:
#
# ---
#
# ### 1. **Thông tin tài nguyên hệ thống**
# - **RAM Usage:** Hiển thị % sử dụng RAM toàn hệ thống.
#   - Ví dụ: `RAM Usage: 51.0%` – Hệ thống đang sử dụng 51% RAM.
#   - `Used RAM: 113.20GB` – Tổng RAM đã sử dụng là 113.20GB.
#   - `Available RAM: 123.23GB` – RAM còn khả dụng là 123.23GB.
#
# - **GPU Memory Usage:**
#   - `GPU 0 Memory Usage: 8319.0MB/24576.0MB (33.9%)` – GPU 0 đang sử dụng 8,319MB trên tổng 24,576MB (khoảng 33.9%).
#   - `GPU 1 Memory Usage: 15085.0MB/24576.0MB (61.4%)` – GPU 1 đang sử dụng 15,085MB (61.4%).
#   - Điều này cho thấy bạn đang sử dụng 2 GPU và cả 2 đều có mức sử dụng bộ nhớ hợp lý.
#
# ---
#
# ### 2. **Training Progress**
# Các log liên quan đến huấn luyện tại từng step và epoch:
#
# - **Epoch:** Số epoch đã hoàn thành.
#   - Ví dụ: `epoch: 76.0` – Mô hình đã hoàn thành epoch thứ 76.
#   - Tương tự, `epoch: 80.0` cho thấy mô hình đã đến epoch 80.
#
# - **Loss:**
#   - `loss` là giá trị hàm mất mát (loss) tại step hiện tại.
#   - Ví dụ: `{'loss': 0.0073}` cho thấy tại một bước huấn luyện, hàm mất mát rất nhỏ, nghĩa là mô hình đang học tốt.
#
# - **Learning Rate:**
#   - `learning_rate` là tốc độ học tại step hiện tại. Ví dụ: `learning_rate: 4.2357142857142864e-05` tương đương `4.24e-05` hoặc 0.00004235.
#
# - **Grad Norm:**
#   - `grad_norm` là giá trị norm của gradient, một chỉ số cho biết kích thước gradient. Ví dụ: `grad_norm: 15.206793785095215` cho thấy gradient tương đối lớn tại bước này.
#
# ---
#
# ### 3. **Evaluation Results**
# Sau mỗi epoch, mô hình được đánh giá trên tập `validation` với các chỉ số:
#
# - **Accuracy:**
#   - Độ chính xác của mô hình trên tập `validation`.
#   - Ví dụ: `eval_accuracy: 0.8355704697986577` tương đương 83.56%.
#
# - **F1 Score:**
#   - Chỉ số F1-Score đánh giá cân bằng giữa Precision và Recall.
#   - Ví dụ: `eval_f1: 0.8359292255357214` tương đương F1-Score là 83.59%.
#
# - **Loss:**
#   - Giá trị hàm mất mát trên tập `validation`.
#   - Ví dụ: `eval_loss: 1.386269211769104` cho thấy mức độ lỗi trên tập validation.
#
# - **Runtime và Throughput:**
#   - `eval_runtime: 0.3902` – Thời gian chạy đánh giá là 0.3902 giây.
#   - `eval_samples_per_second: 763.784` – Đánh giá được 763.78 mẫu mỗi giây.
#   - `eval_steps_per_second: 12.815` – Xử lý 12.82 bước đánh giá mỗi giây.
#
# ---
#
# ### 4. **Diễn biến hiệu suất mô hình**
# - **Tăng giảm Accuracy và F1 Score:**
#   - Accuracy dao động từ khoảng 82% đến 84%, cho thấy mô hình đang học dần dần và cải thiện hiệu suất.
#   - Một số epoch như `82.0` cho thấy `eval_accuracy: 0.8422818791946308` (84.23%) và `eval_f1: 0.8430283646278085` (84.30%), thể hiện mô hình đạt đỉnh hiệu suất tại điểm này.
#
# - **Loss trên tập validation:**
#   - `eval_loss` giảm dần nhưng không đồng đều, từ 1.5543 xuống 1.3863, cho thấy mô hình đang học nhưng có thể gặp một số điểm "local minima" (khu vực mất mát cục bộ).
#
# ---
#
# ### 5. **Nhận xét tổng quan**
# - **Học tốt:** Mô hình có dấu hiệu học tốt với `loss` trên tập train giảm dần và hiệu suất (accuracy, F1) trên tập validation tăng.
# - **Độ ổn định:** Các chỉ số như `accuracy` và `F1 Score` dao động nhẹ quanh giá trị 83–84%, cho thấy mô hình đang đạt đến ngưỡng ổn định.
# - **Gradient Norm:** Một số giá trị `grad_norm` lớn có thể gây bất ổn, nhưng ở cuối (epoch 83.57), `grad_norm: 0.0035` cho thấy gradient đã hội tụ.
# - **Tiềm năng cải thiện:** Bạn có thể thử:
#   - Giảm learning rate khi gần hội tụ.
#   - Sử dụng kỹ thuật như Early Stopping để tránh overfitting.
#   - Điều chỉnh số lượng epoch (có thể không cần đến 500).
#
# ---
#
# Nếu bạn cần hỗ trợ thêm để điều chỉnh cấu hình hoặc phân tích chi tiết hơn, hãy cho mình biết!
